# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/alimughal119/flyrank-ml-internship/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %% [markdown]
# Lane: Content refresh prioritization. I want to explore how existing content can be ranked to identify which pages should be reviewed or improved first. This is useful because editors have limited time and cannot investigate every content item equally. I want to use the available performance data to identify which pages deserve attention first and see whether the data can support a useful prioritization approach.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %% [markdown]
# The decision is which content pages should be reviewed or improved first. Content editors or SEO teams would use the ranking to prioritize their work. A wrong recommendation could waste limited editor time on a low-priority page while a page that needs attention is overlooked.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %% [markdown]
# The starter dataset contains 30,000 content items across 32 clients. The average CTR is 0.51%, showing that the dataset contains measurable performance information that can be used to compare content. This makes content refresh prioritization worth exploring because there are many pages competing for limited editorial attention.

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/alimughal119/flyrank-ml-internship/main/data/raw/content_refresh_anonymized.csv"

df = pd.read_csv(url)

print("Rows:", len(df))
print("Clients:", df["client_id"].nunique())
print("Average CTR:", df["ctr"].mean())
# Out:
# Rows: 30000
# Clients: 32
# Average CTR: 0.5107333333333334

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %% [markdown]
# This work can provide decision-support by identifying patterns in content performance and ranking pages that may deserve review. It can show observed relationships and directional signals in the available data. It cannot prove that changing a page will cause its performance to improve, and it cannot claim to predict future performance with certainty.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
